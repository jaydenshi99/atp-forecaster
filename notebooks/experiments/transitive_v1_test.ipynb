# %% [markdown]
# ## Testing of model Transitive V1
#
# This notebook aims to use cross validation to test the performance of mode Transitive V1.
#
# Transitive V1 is a simple model that instead of predicting matches, aims to predict the probability of a player winning any given point. Then, with dynamic programming we convert the point probabilities to a match win probability. This model only considers two different types of points, service and return points.
#
# We estimate a player's point % win rate against another player by using common opponents. Based on the performance of each player against these common opponents, we estimate the relative serve and return win % between the two plyers.
#
# 2024 data is reserved for the validation set.

# %%
import numpy as np
import pandas as pd

from atp_forecaster.models.transitive_v1 import TransitiveV1
from atp_forecaster.data.clean import get_cleaned_atp_matches

matches = get_cleaned_atp_matches()
matches[matches['tourney_date'] >= 20240101].head()
# Out:
#       surface  draw_size tourney_level  tourney_date    id_a           name_a  \
# 88725    Hard         32             A      20240101  209992   Juncheng Shang
# 88726    Hard         32             A      20240101  209950      Arthur Fils
# 88727    Hard         32             A      20240101  200325  Emil Ruusuvuori
# 88728    Hard         32             A      20240101  209992   Juncheng Shang
# 88729    Hard         32             A      20240101  126094    Andrey Rublev
#
#       hand_a   ht_a  age_a    id_b  ... 2ndWon_b SvGms_b  bpSaved_b  \
# 88725      L  180.0   18.9  126207  ...     11.0    10.0        6.0
# 88726      R  185.0   19.5  126094  ...     15.0    13.0        7.0
# 88727      R  188.0   24.7  124116  ...     22.0    15.0        9.0
# 88728      L  180.0   18.9  126094  ...     19.0    13.0        5.0
# 88729      R  188.0   26.1  200325  ...     12.0    10.0        5.0
#
#        bpFaced_b rank_a  rank_points_a rank_b  rank_points_b  result  order
# 88725        8.0  183.0          335.0   16.0         2310.0       1  88725
# 88726       10.0   36.0         1158.0    5.0         4805.0       0  88726
# 88727       12.0   69.0          771.0   43.0         1048.0       1  88727
# 88728        8.0  183.0          335.0    5.0         4805.0       0  88728
# 88729        7.0    5.0         4805.0   69.0          771.0       1  88729
#
# [5 rows x 42 columns]

# %%
from sklearn.metrics import log_loss, roc_auc_score, accuracy_score

def test_transitive(model, start_date: int, end_date: int):
    """
    Test the performance of the Transitive V1 model over a given date range.
    """
    # Get all matches between start_date and end_date
    train = matches[matches['tourney_date'] < start_date]
    test = matches[(matches['tourney_date'] >= start_date) & (matches['tourney_date'] < end_date)]

    model.fit(train)

    y_pred = []
    y_true = []

    # Predict the outcome of each match in the test set
    for (_, row) in test.iterrows():
        if (len(model.find_common_opponents(row['id_a'], row['id_b'])) < 20):
            continue

        prob = model.predict_match(row['id_a'], row['id_b'])

        y_pred.append(prob)
        y_true.append(row['result'])

        print(row['name_a'], row['name_b'], prob)

        # update model with the match
        model.add_match(row)
    
    y_pred = np.array(y_pred, dtype=float)
    y_true = np.array(y_true, dtype=int)

    loss = log_loss(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    acc = accuracy_score(y_true, (y_pred > 0.5).astype(int))

    return loss, auc, acc

# %%
model = TransitiveV1(
    look_back=720,
    base_spw=0.6
)

loss, auc, acc = test_transitive(model, 20230101, 20230401)
print("Log Loss: ", loss)
print("AUC: ", auc)
print("Accuracy: ", acc)
# Out:
# Sebastian Korda Andy Murray 0.6265577982514196
# Yoshihito Nishioka Holger Rune 0.5305942609345194
# Marcos Giron Richard Gasquet 0.5763675460104118
# Roberto Bautista Agut Andrey Rublev 0.4335501789609936
# Alexei Popyrin Felix Auger Aliassime 0.5343198566587557
# Marcos Giron Alexei Popyrin 0.4477220192870192
# Yoshihito Nishioka Mackenzie Mcdonald 0.5838874369506596
# Roberto Bautista Agut Sebastian Korda 0.45112627341669187
# Jannik Sinner Thanasi Kokkinakis 0.28817261872574595
# Daniil Medvedev Miomir Kecmanovic 0.5460574950856237
# Daniil Medvedev Lorenzo Sonego 0.6148360292769663
# Sebastian Baez Pedro Martinez 0.4619433085634044
# Aslan Karatsev Pedro Martinez 0.585258954831563
# Matteo Berrettini Thiago Monteiro 0.6917965625421453
# Sebastian Korda Jannik Sinner 0.5280959178778248
# Alexander Bublik Hubert Hurkacz 0.43314415679331375
# David Goffin Grigor Dimitrov 0.46701904678603584
# David Goffin Stefanos Tsitsipas 0.49720704371423496
# Cameron Norrie Taylor Fritz 0.4599366156083085
# Matteo Berrettini Hubert Hurkacz 0.5556504546308496
# Matteo Berrettini Stefanos Tsitsipas 0.537703494630626
# Hubert Hurkacz Taylor Fritz 0.6538667746683945
# Lorenzo Musetti Frances Tiafoe 0.37650147880193985
# Matteo Berrettini Taylor Fritz 0.6330049669329059
# Alexander Zverev Taylor Fritz 0.5030280101286756
# Daniel Evans Frances Tiafoe 0.45038407339015357
# Karen Khachanov Daniil Medvedev 0.483776818347953
# Novak Djokovic Denis Shapovalov 0.5957042150693355
# Sebastian Korda Yoshihito Nishioka 0.4052200251090104
# Daniil Medvedev Novak Djokovic 0.5109726183565676
# Novak Djokovic Sebastian Korda 0.5456316382311668
# Casper Ruud Matteo Berrettini 0.39667483707881046
# Albert Ramos Daniel Evans 0.4851972905125853
# Cameron Norrie Rafael Nadal 0.41500018724591303
# Rafael Nadal Alex De Minaur 0.42714236220503143
# Thiago Monteiro Casper Ruud 0.5001851957754199
# Roberto Bautista Agut Alejandro Davidovich Fokina 0.35068442413445516
# John Millman Alejandro Davidovich Fokina 0.6145896117865258
# Mackenzie Mcdonald Daniel Evans 0.40249757172989037
# Albert Ramos John Millman 0.433970703545934
# Brandon Nakashima Alejandro Davidovich Fokina 0.4140287411089585
# Mikael Ymer Emil Ruusuvuori 0.4584528601567425
# Roberto Bautista Agut Soon Woo Kwon 0.40989444946848247
# Richard Gasquet Cameron Norrie 0.34736850070346464
# Jenson Brooksby Cameron Norrie 0.46777063466624735
# Richard Gasquet David Goffin 0.44062902586217984
# Laslo Djere Casper Ruud 0.5538590067327607
# Jenson Brooksby Diego Schwartzman 0.44201917020005066
# Marcos Giron Cameron Norrie 0.5366009660809201
# Federico Coria Marcos Giron 0.3411603938917138
# Jaume Munar Laslo Djere 0.51418046061864
# David Goffin Alexander Bublik 0.3583013645548573
# Grigor Dimitrov Laslo Djere 0.4749409024070589
# Adrian Mannarino Alex De Minaur 0.40690797754853
# Alexei Popyrin Taylor Fritz 0.6186579984124956
# Andrey Rublev Emil Ruusuvuori 0.49563824700170883
# Marton Fucsovics Lloyd Harris 0.5427473749927991
# John Millman Daniil Medvedev 0.44730203240732785
# Lorenzo Sonego Hubert Hurkacz 0.318828094015733
# Alejandro Davidovich Fokina Tommy Paul 0.5119082504604637
# Felix Auger Aliassime Alex Molcan 0.5166211942874763
# Casper Ruud Jenson Brooksby 0.494634243072644
# Frances Tiafoe Karen Khachanov 0.5330180917152945
# Stefanos Tsitsipas Novak Djokovic 0.5304222553200242
# Tommy Paul Novak Djokovic 0.43092019064413584
# Stefanos Tsitsipas Karen Khachanov 0.5525890780061713
# Novak Djokovic Andrey Rublev 0.5617692841579358
# Sebastian Korda Karen Khachanov 0.5254006207347852
# Alex De Minaur Novak Djokovic 0.4802420899068181
# Andrey Rublev Holger Rune 0.5622919979876502
# Jannik Sinner Stefanos Tsitsipas 0.475711339867239
# Sebastian Korda Hubert Hurkacz 0.34939918245245927
# Yoshihito Nishioka Mackenzie Mcdonald 0.5573575701679206
# Karen Khachanov Yoshihito Nishioka 0.5070171113168184
# Andy Murray Roberto Bautista Agut 0.46172198959029526
# Novak Djokovic Grigor Dimitrov 0.6256965199007204
# Holger Rune Ugo Humbert 0.428786315762434
# Andrey Rublev Daniel Evans 0.5314251910920825
# Francisco Cerundolo Felix Auger Aliassime 0.4137241660303248
# Jannik Sinner Marton Fucsovics 0.36099325820265526
# Tallon Griekspoor Stefanos Tsitsipas 0.5265462934552594
# Daniil Medvedev Sebastian Korda 0.5835310136516128
# Hubert Hurkacz Denis Shapovalov 0.5960296568875368
# Jenson Brooksby Tommy Paul 0.4795191712120743
# Mackenzie Mcdonald Rafael Nadal 0.44948320991684676
# Tommy Paul Roberto Bautista Agut 0.5580697639804437
# Lloyd Harris Lorenzo Musetti 0.45782744554593613
# Botic Van De Zandschulp Ilya Ivashka 0.5095730217036141
# Marcos Giron Daniil Medvedev 0.4619231805726384
# Sebastian Korda Cristian Garin 0.5152415334959486
# Denis Shapovalov Dusan Lajovic 0.5478366762459647
# Pedro Martinez Hubert Hurkacz 0.418592260167682
# Mikael Ymer Yoshihito Nishioka 0.4670373329672295
# Mackenzie Mcdonald Brandon Nakashima 0.5187243496423831
# Dominic Thiem Andrey Rublev 0.4045510467760396
# Tommy Paul Jan Lennard Struff 0.4950667250706298
# Alejandro Davidovich Fokina Alexander Bublik 0.5151505567450558
# Roberto Bautista Agut Joao Sousa 0.4314390403397523
# Matteo Berrettini Andy Murray 0.5785807071555098
# Taylor Fritz Nikoloz Basilashvili 0.48710251792792636
# Filip Krajinovic Holger Rune 0.4324746213596116
# Albert Ramos Maxime Cressy 0.4615574735411837
# Adrian Mannarino John Isner 0.4940948861724481
# Grigor Dimitrov Aslan Karatsev 0.36621037601284046
# Maxime Cressy Jannik Sinner 0.5425292406459589
# Jannik Sinner Lorenzo Sonego 0.5952452560143398
# Frances Tiafoe Mackenzie Mcdonald 0.4860923715158082
# Aslan Karatsev Filip Krajinovic 0.49820082665227877
# Ugo Humbert Alejandro Davidovich Fokina 0.4387008695082807
# Mikael Ymer Emil Ruusuvuori 0.49983622127179617
# Lorenzo Sonego Filip Krajinovic 0.4394344469989665
# Maxime Cressy Emil Ruusuvuori 0.37957504379780616
# Francisco Cerundolo Federico Delbonis 0.4989748368668641
# Dusan Lajovic Albert Ramos 0.618247319763688
# Federico Coria Albert Ramos 0.4632375261708736
# Jordan Thompson Adrian Mannarino 0.4807142653809418
# Taylor Fritz Marcos Giron 0.3948223720445318
# Pedro Martinez Cristian Garin 0.6568695764002256
# Grigor Dimitrov Daniil Medvedev 0.5356624119978249
# Jannik Sinner Stefanos Tsitsipas 0.46928209590623426
# Alex De Minaur Grigor Dimitrov 0.6324121128610124
# Jannik Sinner Tallon Griekspoor 0.5169728060188715
# Felix Auger Aliassime Daniil Medvedev 0.42439990261736366
# Daniil Medvedev Jannik Sinner 0.5159156427233904
# Roberto Carballes Baena Albert Ramos 0.4530687900956161
# Andrey Rublev Alex De Minaur 0.4122156473499851
# Aslan Karatsev Grigor Dimitrov 0.6739768410182635
# Hubert Hurkacz Roberto Bautista Agut 0.6710337834819415
# Lorenzo Sonego Felix Auger Aliassime 0.4928837115341538
# Alejandro Davidovich Fokina Daniil Medvedev 0.4950765252892084
# Botic Van De Zandschulp Daniil Medvedev 0.5485439209833297
# Alexander Zverev Soon Woo Kwon 0.4641221420443902
# Richard Gasquet Pablo Carreno Busta 0.5723785592584857
# Jannik Sinner Benjamin Bonzi 0.3932246088286852
# Emil Ruusuvuori Stefanos Tsitsipas 0.4895158883451576
# Alex De Minaur Maxime Cressy 0.5785448724395424
# Grigor Dimitrov Hubert Hurkacz 0.4210054467322485
# Yoshihito Nishioka Mackenzie Mcdonald 0.546954302966862
# Miomir Kecmanovic Marcos Giron 0.49027469645497523
# Adrian Mannarino Taylor Fritz 0.49245343301758854
# Taylor Fritz Mackenzie Mcdonald 0.4032004636615795
# Fabio Fognini Laslo Djere 0.48392936759955546
# Miomir Kecmanovic Taylor Fritz 0.6482097877070435
# Laslo Djere Carlos Alcaraz 0.40039768326035713
# Carlos Alcaraz Cameron Norrie 0.6306916548455882
# Carlos Alcaraz Dusan Lajovic 0.5881588553982119
# Hubert Hurkacz Benjamin Bonzi 0.44724840460235915
# Alexander Bublik Hubert Hurkacz 0.44864685009971117
# Pedro Martinez Cristian Garin 0.6568695764002256
# Dusan Lajovic Diego Schwartzman 0.6078160648192109
# Mikael Ymer Hubert Hurkacz 0.48951215125391656
# Alexander Bublik Filip Krajinovic 0.5521479506224187
# Alexander Bublik Grigor Dimitrov 0.5040006964949307
# Cameron Norrie Thiago Monteiro 0.5231949675558869
# Alejandro Davidovich Fokina Soon Woo Kwon 0.45347651619244855
# Andrey Rublev Tallon Griekspoor 0.5481044345293017
# Felix Auger Aliassime Alejandro Davidovich Fokina 0.4284938385974123
# Daniil Medvedev Felix Auger Aliassime 0.5802808844088172
# Andy Murray Daniil Medvedev 0.5306391376929908
# Emil Ruusuvuori Daniel Evans 0.5091607249698081
# Lorenzo Sonego Andy Murray 0.42071588616909167
# Andy Murray Alexander Zverev 0.4118884141882851
# Botic Van De Zandschulp Ilya Ivashka 0.5284060071303373
# Dusan Lajovic Laslo Djere 0.6286775230964633
# Fabio Fognini Carlos Alcaraz 0.5293173880514457
# Dusan Lajovic Carlos Alcaraz 0.45595582681661145
# Carlos Alcaraz Cameron Norrie 0.6320758832995648
# Roberto Bautista Agut Marton Fucsovics 0.39422371681772084
# Botic Van De Zandschulp Karen Khachanov 0.5559988198427015
# Felix Auger Aliassime Maxime Cressy 0.33091507252313984
# Filip Krajinovic Andrey Rublev 0.47392454246685245
# Alejandro Davidovich Fokina Andrey Rublev 0.4792959019677244
# Lorenzo Musetti Jaume Munar 0.5826899291288113
# Laslo Djere Sebastian Baez 0.5138381037387566
# Mikael Ymer Botic Van De Zandschulp 0.436798792257531
# Casper Ruud Taro Daniel 0.4604969158275901
# Taylor Fritz Denis Shapovalov 0.3729718361255302
# Mackenzie Mcdonald Brandon Nakashima 0.4624848999539974
# Holger Rune Matteo Berrettini 0.37794817171362594
# Taylor Fritz Frances Tiafoe 0.3008936834917041
# Tommy Paul Mackenzie Mcdonald 0.4710830491539631
# Alex De Minaur Holger Rune 0.6190243044257346
# Taylor Fritz Tommy Paul 0.36637058527917055
# Alex De Minaur Tommy Paul 0.4575607580301531
# Lorenzo Sonego Felix Auger Aliassime 0.4876982573270164
# Taylor Fritz John Isner 0.4885254608719917
# Denis Shapovalov Miomir Kecmanovic 0.5252089368214541
# Frances Tiafoe Yoshihito Nishioka 0.47197459681305814
# Daniil Medvedev Alexander Bublik 0.5687151793235605
# Andrey Rublev Botic Van De Zandschulp 0.39210809963601123
# Hubert Hurkacz Novak Djokovic 0.5910358998721167
# Alexander Zverev Andrey Rublev 0.5830819080885788
# Novak Djokovic Daniil Medvedev 0.4502673042796691
# Alexander Zverev Lorenzo Sonego 0.5553322760620286
# Alex Molcan Matteo Berrettini 0.47379980304370695
# Andrey Rublev Daniil Medvedev 0.508013714076864
# Jordan Thompson Stefanos Tsitsipas 0.49007193140119965
# Denis Shapovalov Ugo Humbert 0.6500233430301438
# Diego Schwartzman Casper Ruud 0.45592700014152837
# Oscar Otte Karen Khachanov 0.42952519317212023
# Marcos Giron Frances Tiafoe 0.5114986696165575
# Alex Molcan Albert Ramos 0.6135898702113749
# Emil Ruusuvuori Roberto Bautista Agut 0.5782033387591871
# Diego Schwartzman Federico Coria 0.47442202362609626
# Mackenzie Mcdonald Filip Krajinovic 0.5473021695363665
# Daniil Medvedev Brandon Nakashima 0.5012119392698491
# Ilya Ivashka Botic Van De Zandschulp 0.49273006695444893
# Daniil Medvedev Carlos Alcaraz 0.4891958284480181
# Felix Auger Aliassime Francisco Cerundolo 0.554404223731972
# Hubert Hurkacz Tommy Paul 0.6073812773156841
# Carlos Alcaraz Tallon Griekspoor 0.46860079122169385
# Cameron Norrie Andrey Rublev 0.30726325544086514
# Daniil Medvedev Alexander Zverev 0.4413453312210532
# Jannik Sinner Adrian Mannarino 0.4391015922259729
# Felix Auger Aliassime Tommy Paul 0.47849275511333955
# Carlos Alcaraz Jack Draper 0.48833083692205753
# Frances Tiafoe Cameron Norrie 0.6801043614045444
# Daniil Medvedev Alejandro Davidovich Fokina 0.5250709110837052
# Jannik Sinner Taylor Fritz 0.4384657873117955
# Felix Auger Aliassime Carlos Alcaraz 0.4666751569892247
# Frances Tiafoe Daniil Medvedev 0.568127941083575
# Carlos Alcaraz Jannik Sinner 0.5858914301893561
# Holger Rune Mackenzie Mcdonald 0.47689569731195663
# Marton Fucsovics Taylor Fritz 0.5005242909266288
# Cristian Garin Alejandro Davidovich Fokina 0.4857463687103579
# Emil Ruusuvuori Alexander Zverev 0.45118638997418425
# Ilya Ivashka Daniil Medvedev 0.5754659716773435
# Lorenzo Musetti Adrian Mannarino 0.5939361537731073
# Richard Gasquet Jannik Sinner 0.46483084150929105
# Marton Fucsovics Alex De Minaur 0.5093708445515436
# Pedro Martinez Felix Auger Aliassime 0.46442081256742135
# Alexei Popyrin Hubert Hurkacz 0.2567324194310538
# Alejandro Davidovich Fokina Karen Khachanov 0.5228898076668229
# Cameron Norrie Taro Daniel 0.44964110472772023
# Andrey Rublev Ugo Humbert 0.6157743218969227
# Cristian Garin Casper Ruud 0.5987999118735268
# Andy Murray Dusan Lajovic 0.46941125682430096
# Daniel Evans Lorenzo Sonego 0.5309197824188194
# Mackenzie Mcdonald Matteo Berrettini 0.5281863295094101
# Cristian Garin Marcos Giron 0.4915891454891451
# Dominic Thiem Lorenzo Sonego 0.6176544181328955
# Botic Van De Zandschulp Casper Ruud 0.6571321840920304
# Holger Rune Diego Schwartzman 0.4614919042968396
# Denis Shapovalov Taylor Fritz 0.639963409776306
# Alejandro Davidovich Fokina Tommy Paul 0.5139886195458102
# Dusan Lajovic Carlos Alcaraz 0.4776559808298894
# Karen Khachanov Stefanos Tsitsipas 0.4614511958007248
# Francisco Cerundolo Lorenzo Sonego 0.45877384216968936
# Jannik Sinner Andrey Rublev 0.5110610750186035
# Taylor Fritz Holger Rune 0.45916544374040524
# Tommy Paul Carlos Alcaraz 0.5645732974668204
# Karen Khachanov Francisco Cerundolo 0.6398351834218955
# Emil Ruusuvuori Jannik Sinner 0.6362058397248179
# Taylor Fritz Carlos Alcaraz 0.44120843281443733
# Carlos Alcaraz Jannik Sinner 0.5694884455367096
# Daniil Medvedev Jannik Sinner 0.5137966527637934
# Emil Ruusuvuori Botic Van De Zandschulp 0.4412330632488791
# Grigor Dimitrov Jannik Sinner 0.5673207182951876
# Karen Khachanov Daniil Medvedev 0.5101902249410291
# Adrian Mannarino Hubert Hurkacz 0.28662280392385725
# Grigor Dimitrov Jan Lennard Struff 0.46188917090378884
# Miomir Kecmanovic Andrey Rublev 0.4974794087556891
# Laslo Djere Jannik Sinner 0.5466599036955189
# Roberto Bautista Agut Emil Ruusuvuori 0.3746161417675482
# Ilya Ivashka Casper Ruud 0.5936991942688731
# Marton Fucsovics Holger Rune 0.5347153709606971
# Brandon Nakashima Alejandro Davidovich Fokina 0.3666989343494609
# Lorenzo Sonego Frances Tiafoe 0.40169021923588555
# Francisco Cerundolo Felix Auger Aliassime 0.46767830176821623
# Cristian Garin Stefanos Tsitsipas 0.4924431276480625
# Log Loss:  0.7067516617441307
# AUC:  0.5111301369863014
# Accuracy:  0.5296296296296297
